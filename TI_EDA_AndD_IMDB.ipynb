# %% [markdown]
# <a href="https://colab.research.google.com/github/marianoMarchetta1/ADD-UBA/blob/main/TI_EDA_AndD_IMDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub
import os
import pandas as pd
import numpy as np

path = kagglehub.dataset_download("asaniczka/tmdb-movies-dataset-2023-930k-movies")
print("Path to dataset files:", path)

for f in os.listdir(path):
    print(f)

csv_path = os.path.join(path, "TMDB_movie_dataset_v11.csv")
movies_df = pd.read_csv(csv_path, low_memory=False)
# Out:
# ...
# 100%|██████████| 253M/253M [00:01<00:00, 175MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/asaniczka/tmdb-movies-dataset-2023-930k-movies/versions/1060
# TMDB_movie_dataset_v11.csv

# %%
print(f"Dimensiones del dataset original: {movies_df.shape}")
movies_df.head()
# Out:
# Dimensiones del dataset original: (1495779, 24)
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   2010-07-15
# 1  157336     Interstellar         8.417       32571  Released   2014-11-05
# 2     155  The Dark Knight         8.512       30619  Released   2008-07-16
# 3   19995           Avatar         7.573       29815  Released   2009-12-15
# 4   24428     The Avengers         7.710       29166  Released   2012-04-25
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
# ...

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1495779 entries, 0 to 1495778
# Data columns (total 24 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   id                    1495779 non-null  int64
#  1   title                 1495760 non-null  object
#  2   vote_average          1495779 non-null  float64
#  3   vote_count            1495779 non-null  int64
#  4   status                1495779 non-null  object
#  5   release_date          1142763 non-null  object
#  6   revenue               1495779 non-null  int64
#  7   runtime               1495779 non-null  int64
#  8   adult                 1495779 non-null  bool
#  9   backdrop_path         364736 non-null   object
#  10  budget                1495779 non-null  int64
#  11  homepage              153071 non-null   object
#  12  imdb_id               686056 non-null   object
#  13  original_language     1495779 non-null  object
# ...

# %%
nulos = movies_df.isnull().sum()
porcentaje = (nulos / len(movies_df) * 100).round(2)

resumen_nulos = pd.DataFrame({
    'Nulos': nulos,
    'Porcentaje (%)': porcentaje
}).sort_values(by='Porcentaje (%)', ascending=False)

resumen_nulos[resumen_nulos['Nulos'] > 0]
# Out:
#                         Nulos  Porcentaje (%)
# homepage              1342708           89.77
# tagline               1286349           86.00
# keywords              1132590           75.72
# backdrop_path         1131043           75.62
# production_companies   867743           58.01
# imdb_id                809723           54.13
# production_countries   738451           49.37
# spoken_languages       709222           47.41
# genres                 670765           44.84
# poster_path            545080           36.44
# release_date           353016           23.60
# overview               347856           23.26
# title                      19            0.00
# original_title             19            0.00

# %%
# Fechas
movies_df['release_date'] = pd.to_datetime(movies_df['release_date'], errors='coerce')

# Categóricas de baja cardinalidad
for col in ['status', 'original_language']:
    movies_df[col] = movies_df[col].astype('category')

# %%
movies_df.dtypes
# Out:
# id                               int64
# title                           object
# vote_average                   float64
# vote_count                       int64
# status                        category
# release_date            datetime64[ns]
# revenue                          int64
# runtime                          int64
# adult                             bool
# backdrop_path                   object
# budget                           int64
# homepage                        object
# imdb_id                         object
# original_language             category
# original_title                  object
# overview                        object
# popularity                     float64
# poster_path                     object
# tagline                         object
# genres                          object
# production_companies            object
# production_countries            object
# spoken_languages                object
# keywords                        object
# dtype: object

# %%
movies_df.describe()
# Out:
#                  id  vote_average    vote_count  \
# count  1.495779e+06  1.495779e+06  1.495779e+06
# mean   9.418425e+05  1.487509e+00  1.434695e+01
# min    2.000000e+00  0.000000e+00  0.000000e+00
# 25%    5.171675e+05  0.000000e+00  0.000000e+00
# 50%    9.675280e+05  0.000000e+00  0.000000e+00
# 75%    1.376962e+06  0.000000e+00  0.000000e+00
# max    1.770856e+06  1.000000e+01  3.449500e+04
# std    5.001019e+05  2.817324e+00  2.777689e+02
#
#                         release_date       revenue       runtime  \
# count                        1142763  1.495779e+06  1.495779e+06
# mean   2001-12-01 17:55:31.578989056  6.085337e+05  4.314418e+01
# min              1800-01-01 00:00:00 -1.200000e+01 -2.800000e+01
# 25%              1992-01-01 00:00:00  0.000000e+00  0.000000e+00
# 50%              2012-04-18 00:00:00  0.000000e+00  1.500000e+01
# 75%              2020-06-05 00:00:00  0.000000e+00  8.400000e+01
# max              2099-12-31 00:00:00  5.000000e+09  1.440000e+04
# ...

# %%
movies_df.describe(include=['category', 'bool'])
# Out:
#           status    adult original_language
# count    1495779  1495779           1495779
# unique         6        2               179
# top     Released    False                en
# freq     1438164  1347645            821652
